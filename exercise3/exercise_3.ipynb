# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis

import seaborn as sns
sns.set(style='whitegrid')

# %%
df = pd.read_csv("generated_his_system_metrics.csv", index_col=0)
df.head()
# Out:
#            sensor_latency_ms  cpu_usage_percent  memory_usage_mb  error_count  \
# system_id
# 1                  22.483571          58.892663       420.457194            0
# 2                  19.308678          73.641250       316.802495            0
# 3                  23.238443          24.021486       174.484049            1
# 4                  27.615149          53.444539        96.321615            0
# 5                  18.829233          35.240361       311.006058            2
#
#            uptime_hours       mode  temperature_sensor  CPU_temperature  \
# system_id
# 1            130.837373     normal           26.146247             50.9
# 2             48.285983     normal           56.447908             59.1
# 3             92.523906     normal           57.172326             48.8
# 4             63.130883  emergency           28.567063             42.7
# 5             47.978239     normal           31.508234             46.8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 1 to 500
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   sensor_latency_ms            500 non-null    float64
#  1   cpu_usage_percent            500 non-null    float64
#  2   memory_usage_mb              500 non-null    float64
#  3   error_count                  500 non-null    int64
#  4   uptime_hours                 500 non-null    float64
#  5   mode                         500 non-null    str
#  6   temperature_sensor           500 non-null    float64
#  7   CPU_temperature              500 non-null    float64
#  8   CPU_thermostat_stability     500 non-null    float64
#  9   sensor_thermostat_stability  500 non-null    float64
# dtypes: float64(8), int64(1), str(1)
# memory usage: 39.2 KB

# %% [markdown]
# Classify each variable as:
# - Categorical(Nominal/Ordinal)
# - Numerical (Discrete/Continuous)

# %%
categorial_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_31536\1976110146.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorial_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()

# %% [markdown]
# - When is a histogram preferable to a bar plot?
# - "when the variables are numerical"
# - Plot the histogram for the different variables

# %%
df[numerical_cols].hist(bins=30, figsize=(10, 8), color='skyblue', edgecolor='black')
plt.suptitle('Histograms of Numeric Features')
plt.tight_layout()
plt.show()
